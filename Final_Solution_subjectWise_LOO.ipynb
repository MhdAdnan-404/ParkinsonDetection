# %%
from __future__ import annotations

# =========================
# Determinism (set BEFORE importing torch)
# =========================
import os  # [DET]

os.environ.setdefault("CUBLAS_WORKSPACE_CONFIG", ":16:8")  # [DET]

import re
from pathlib import Path
from collections import Counter, defaultdict
from typing import List, Tuple, Dict, Optional

import numpy as np
import random
import hashlib  # [DET]
import warnings

warnings.filterwarnings(
    "ignore", message=".*gpu_hist.*deprecated.*", category=UserWarning
)
warnings.filterwarnings(
    "ignore",
    message='.*Parameters: { "predictor" } are not used.*',
    category=UserWarning,
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.transforms import InterpolationMode
from torchvision.models import resnet18, ResNet18_Weights
from PIL import Image

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

import timm

# =========================
# Config
# =========================
DATA_ROOT = Path(
    r"/mnt/c/Users/adnan/Desktop/_/MachineLearning/ML/DATA/PD_Detection_NewHandPD_Dataset"
)
OUTDIR = Path("checkpoints_subject5cv_per_draw_tiles_WINS")

DRAW_TYPES = ["circle","meander","spiral"]

EPOCHS_FN = {"circle": 5, "meander": 10, "spiral": 5}
LR_INIT = {"circle": 3.16e-4, "meander": 1e-3, "spiral": 3.16e-4}
BATCH_SIZE = {"circle": 64, "meander": 16, "spiral": 16}
LS_EPS = {"circle": 0.05, "meander": 0.05, "spiral": 0.0}
WEIGHT_DECAY = {"circle": 1e-4, "meander": 0.0, "spiral": 1e-4}
NUM_WORKERS = 4
SEED = 42

PRINT_PATHS = False

# ---- Tiling
TILE_GRID = (2, 2)  # 2×2 tiles per image
TILE_RESIZE_BASE = 448  # resize to 448, then crop 4×(224×224)
FINAL_SIZE = 224


# ---- Feature backbone mode (your best runs used resnet features)
FEAT_MODE = "resnet"

# ---- Deterministic full-image augmentation repeats
REPEATS_BY_DRAW = {
    "circle": 4,  # fixed rotations over 360°
    "meander": 2,  # deterministic Gaussian noise draws
    "spiral": 2,  # deterministic Gaussian noise draws
}

# ---- WINNING CLASSIFIER SPECS (fixed; from your “best” logs)
# Circle (KNN): scaler=StandardScaler, no PCA, n_neighbors=1, p=1, weights=uniform, leaf_size=15
# Meander (DT):  gini, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=None, class_weight=None
# Spiral (RF):   n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features='sqrt',
#                class_weight=None, n_jobs=-1
WINNERS = {
    "circle": Pipeline(
        [
            ("scaler", StandardScaler(with_mean=True, with_std=True)),
            (
                "clf",
                KNeighborsClassifier(
                    n_neighbors=1,
                    weights="uniform",
                    p=1,
                    metric="minkowski",
                    leaf_size=15,
                ),
            ),
        ]
    ),
    "meander": Pipeline(
        [
            (
                "clf",
                DecisionTreeClassifier(
                    random_state=SEED,
                    criterion="gini",
                    max_depth=None,
                    min_samples_split=2,
                    min_samples_leaf=1,
                    max_features=None,
                    class_weight=None,
                ),
            ),
        ]
    ),
    "spiral": Pipeline(
        [
            (
                "clf",
                KNeighborsClassifier(
                    n_neighbors=1,
                    weights="uniform",
                    p=1,
                    metric="minkowski",
                    leaf_size=15,
                ),
            ),
        ]
    ),
}


# =========================
# Repro / determinism
# =========================
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False  # [DET]
    torch.backends.cudnn.deterministic = True  # [DET]
    torch.backends.cuda.matmul.allow_tf32 = False  # [DET]
    torch.backends.cudnn.allow_tf32 = False  # [DET]
    torch.use_deterministic_algorithms(True)  # [DET]


set_seed(SEED)


# ---------- Deterministic DataLoader helpers ----------
def _seed_from_key(base_seed: int, *parts: str) -> int:  # [DET]
    h = hashlib.sha256()
    h.update(str(base_seed).encode())
    for p in parts:
        h.update(str(p).encode())
    return int.from_bytes(h.digest()[:8], "little")


def _worker_init_fn(worker_id: int):  # [DET]
    ws = torch.initial_seed() % (2**32)
    np.random.seed(ws)
    random.seed(ws)


def _make_loader(
    dataset,
    *,
    shuffle: bool,
    num_workers: int,
    base_seed: int,
    key: str,
    batch_size: int,
):  # [DET]
    g = torch.Generator(device="cpu")
    g.manual_seed(_seed_from_key(base_seed, key))
    return DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=num_workers,
        pin_memory=True,
        worker_init_fn=_worker_init_fn,
        generator=g,
        persistent_workers=False,
        drop_last=False,
    )


# ---------- Fold-level reseed to lock init per draw×fold ----------
def make_fold_seed(*parts: str) -> int:
    h = hashlib.sha256()
    h.update(str(SEED).encode())
    for p in parts:
        h.update(str(p).encode())
    return int.from_bytes(h.digest()[:8], "little")


def reseed_for_fold(draw: str, fold_idx: int):
    s = make_fold_seed("fold", draw, str(fold_idx))
    random.seed(s)
    np.random.seed(s % (2**32))
    torch.manual_seed(s)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(s)


# ------------------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# =========================
# Data discovery (DETERMINISTIC)
# =========================
_SUBJ_PAT = re.compile(r"(?i)-([HP])0*(\d+)$")
_SUBJ_ANY = re.compile(r"(?i)-([HP])0*(\d+)\b")


def extract_subject_id(fp: str) -> str:
    stem = Path(fp).stem
    m = _SUBJ_PAT.search(stem) or _SUBJ_ANY.search(stem)
    if not m:
        raise ValueError(f"[subject_id] Could not parse subject from: {fp}")
    prefix = m.group(1).upper()
    num = str(int(m.group(2)))
    return f"{prefix}{num}"


_DRAW_MAP = {
    "circle": ["circle", "circ"],
    "meander": ["meander", "meand", "wave", "wav"],
    "spiral": ["spiral", "spir", "sp"],
}


def _norm_draw_folder(name: str):
    s = name.lower()
    for canon, toks in _DRAW_MAP.items():
        if any(tok == s or tok in s for tok in toks):
            return canon
    return None


def discover_items_tree(data_root: Path) -> List[Tuple[str, int, str, str]]:
    exts = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}
    items: List[Tuple[str, int, str, str]] = []
    seen: set[str] = set()

    for hlab_name, lab in [("Healthy", 0), ("Patient", 1)]:
        lab_dir = data_root / hlab_name
        if not lab_dir.exists():
            print(f"[warn] Missing folder: {lab_dir}")
            continue
        for sub in sorted(lab_dir.iterdir(), key=lambda p: p.name.lower()):
            if not sub.is_dir():
                continue
            d = _norm_draw_folder(sub.name)
            if d is None:
                continue
            files = sorted(
                (p for p in sub.rglob("*") if p.is_file() and p.suffix.lower() in exts),
                key=lambda p: str(p).lower(),
            )
            for p in files:
                rp = str(p.resolve())
                if rp in seen:
                    continue
                seen.add(rp)
                sid = extract_subject_id(rp)
                items.append((rp, lab, d, sid))

    items.sort(key=lambda t: (t[1], t[2], t[3], t[0]))
    print(f"[info] Found {len(items)} images")
    if items:
        print("  by label    :", Counter([lab for _, lab, _, _ in items]))
        print("  by draw type:", Counter([d for _, _, d, _ in items]))
        print("  subjects    :", len(set([sid for *_, sid in items])))
    return items


# =========================
# Transforms / Tiling (per-image max only; NO mean/std)
# =========================
class PerImageMaxNormalize(object):
    def __call__(self, img: torch.Tensor):
        cmax = torch.amax(img, dim=(1, 2), keepdim=True)
        return img / (cmax + 1e-8)


_RESIZE_448 = transforms.Resize(
    (TILE_RESIZE_BASE, TILE_RESIZE_BASE), interpolation=InterpolationMode.BILINEAR
)
_TO_TENSOR = transforms.ToTensor()
_TO_PIL = transforms.ToPILImage()
_NORM_PERIMG = PerImageMaxNormalize()


def _resize_to_base(pil_img: Image.Image) -> Image.Image:
    return _RESIZE_448(pil_img)


def _crop_tile_from_resized(
    pil_img_448: Image.Image, tile_index: int, rows: int = 2, cols: int = 2
) -> Image.Image:
    W, H = pil_img_448.size
    tile_w, tile_h = W // cols, H // rows
    r = tile_index // cols
    c = tile_index % cols
    left = c * tile_w
    top = r * tile_h
    return pil_img_448.crop((left, top, left + tile_w, top + tile_h))


def _tile_to_tensor(pil_tile: Image.Image) -> torch.Tensor:
    t = _TO_TENSOR(pil_tile)  # [0,1]
    t = _NORM_PERIMG(t)
    return t


# =========================
# Deterministic full-image augmentation (applied BEFORE tiling)
# =========================
def _hash_int(s: str) -> int:
    return int.from_bytes(hashlib.sha256(s.encode()).digest()[:8], "little")


def _angle_for_repeat(
    total_repeats: int,
    repeat_idx: int,
    min_angle: float = 0.0,
    max_angle: float = 360.0,
) -> float:
    if total_repeats <= 1:
        return 0.0
    step = (max_angle - min_angle) / total_repeats
    return min_angle + step * (repeat_idx % total_repeats)


def augment_full_image_deterministic(
    pil_img: Image.Image, draw: str, fp: str, repeat_idx: int
) -> Image.Image:
    img = _resize_to_base(pil_img)
    if draw == "circle":
        angle = _angle_for_repeat(REPEATS_BY_DRAW.get("circle", 1), repeat_idx)
        img = transforms.functional.rotate(
            img, angle, interpolation=InterpolationMode.BILINEAR, expand=False, fill=255
        )
        return img
    repeats = REPEATS_BY_DRAW.get(draw, 1)
    if repeats > 1:
        key = f"{SEED}|noise|{draw}|{fp}|rep{repeat_idx}"
        gen = torch.Generator(device="cpu")
        gen.manual_seed(_hash_int(key))
        x = _TO_TENSOR(img)
        std = 0.003
        noise = torch.randn(x.size(), generator=gen) * std
        x = (x + noise).clamp(0.0, 1.0)
        img = _TO_PIL(x)
    return img


# =========================
# Datasets
# =========================
def _prf(tp: int, fp: int, fn: int):
    prec = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    rec = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = (2 * prec * rec / (prec + rec)) if (prec + rec) > 0 else 0.0
    return prec, rec, f1


class TrainTilesAugFirstDataset(Dataset):
    def __init__(self, items):
        self.records = []  # (fp, lab, draw, sid, repeat_idx, tile_index)
        for fp, lab, d, sid in items:
            repeats = max(1, int(REPEATS_BY_DRAW.get(d, 1)))
            for rep in range(repeats):
                for tile_idx in range(TILE_GRID[0] * TILE_GRID[1]):
                    self.records.append((fp, int(lab), d, sid, rep, tile_idx))

    def __len__(self):
        return len(self.records)

    def __getitem__(self, i):
        fp, lab, d, sid, rep, tile_idx = self.records[i]
        pil_img = Image.open(fp).convert("RGB")
        aug_img = augment_full_image_deterministic(pil_img, d, fp, rep)
        pil_tile = _crop_tile_from_resized(aug_img, tile_idx, *TILE_GRID)
        x = _tile_to_tensor(pil_tile)
        return x, lab


class TilesWithMetaDataset(Dataset):
    def __init__(self, items):
        self.records = []  # (fp, lab, sid, tile_index)
        for fp, lab, _d, sid in items:
            for tile_idx in range(TILE_GRID[0] * TILE_GRID[1]):
                self.records.append((fp, int(lab), sid, tile_idx))

    def __len__(self):
        return len(self.records)

    def __getitem__(self, i):
        fp, lab, sid, tile_idx = self.records[i]
        pil_img = Image.open(fp).convert("RGB")
        img448 = _resize_to_base(pil_img)
        pil_tile = _crop_tile_from_resized(img448, tile_idx, *TILE_GRID)
        x = _tile_to_tensor(pil_tile)
        return x, lab, sid, fp


# =========================
# Backbone model (feature extractor)
# =========================
class ResNetPVTRep(nn.Module):
    def __init__(
        self,
        mode: str = "both",
        *,
        resnet_pretrained: bool = True,
        pvt_pretrained: bool = False,
        hidden1: int = 512,
        hidden2: Optional[int] = 512,
        dropout: float = 0.0,
        freeze_backbones: bool = False,
    ):
        super().__init__()
        assert mode in {"resnet", "pvt", "both"}
        self.mode = mode

        self.resnet = None
        res_dim = 0
        if mode in {"resnet", "both"}:
            self.resnet = resnet18(
                weights=ResNet18_Weights.IMAGENET1K_V1 if resnet_pretrained else None
            )
            res_dim = self.resnet.fc.in_features  # 512
            self.resnet.fc = nn.Identity()

        self.pvt = None
        pvt_dim = 0
        if mode in {"pvt", "both"}:
            self.pvt = timm.create_model(
                "pvt_v2_b1",
                pretrained=pvt_pretrained,
                num_classes=0,
                global_pool="avg",
            )
            pvt_dim = getattr(self.pvt, "num_features", 512)

        fused_dim = res_dim + pvt_dim

        layers = [nn.Linear(fused_dim, hidden1), nn.ReLU(inplace=True)]
        if dropout and dropout > 0:
            layers.append(nn.Dropout(dropout))
        if hidden2 is None:
            layers.append(nn.Linear(hidden1, 2))
        else:
            layers.extend(
                [
                    nn.Linear(hidden1, hidden2),
                    nn.ReLU(inplace=True),
                    nn.Linear(hidden2, 2),
                ]
            )
        self.head = nn.Sequential(*layers)

        if freeze_backbones:
            if self.resnet is not None:
                for p in self.resnet.parameters():
                    p.requires_grad = False
            if self.pvt is not None:
                for p in self.pvt.parameters():
                    p.requires_grad = False

    def forward(self, x):
        feats = []
        if self.resnet is not None:
            feats.append(self.resnet(x))
        if self.pvt is not None:
            feats.append(self.pvt(x))
        z = feats[0] if len(feats) == 1 else torch.cat(feats, dim=1)
        return self.head(z)

    @torch.no_grad()
    def tile_features(self, x):
        feats = []
        if self.resnet is not None:
            feats.append(self.resnet(x))
        if self.pvt is not None:
            feats.append(self.pvt(x))
        return feats[0] if len(feats) == 1 else torch.cat(feats, dim=1)


def make_backbone_model(
    mode: str = "both",
    *,
    hidden1: int = 128,
    hidden2: Optional[int] = None,
    dropout: float = 0.0,
    freeze_backbones: bool = False,
    resnet_pretrained: bool = True,
    pvt_pretrained: bool = True,
) -> nn.Module:
    return ResNetPVTRep(
        mode=mode,
        resnet_pretrained=resnet_pretrained,
        pvt_pretrained=pvt_pretrained,
        hidden1=hidden1,
        hidden2=hidden2,
        dropout=dropout,
        freeze_backbones=freeze_backbones,
    )


# =========================
# Inference helpers (tile → image features)
# =========================
@torch.no_grad()
def collect_image_features(
    model: ResNetPVTRep, items: List[Tuple[str, int, str, str]], device
):
    ds = TilesWithMetaDataset(items)
    dl = _make_loader(
        ds,
        batch_size=32,
        shuffle=False,
        num_workers=NUM_WORKERS,
        base_seed=SEED,
        key="FEATS",
    )
    model.eval()

    feats_by_key: Dict[str, List[np.ndarray]] = defaultdict(list)
    labels_by_key: Dict[str, int] = {}
    sid_by_key: Dict[str, str] = {}

    for xb, yb, sidb, imgkey in dl:
        xb = xb.to(device, non_blocking=True)
        z = model.tile_features(xb).detach().cpu().numpy()
        yb = yb.numpy()
        for zi, lab, sid, k in zip(z, yb, sidb, imgkey):
            feats_by_key[k].append(zi)
            labels_by_key[k] = int(lab)
            sid_by_key[k] = str(sid)

    X_list, y_list, sid_list, key_list = [], [], [], []
    for k in sorted(feats_by_key.keys()):
        arr = np.stack(feats_by_key[k], axis=0)  # [num_tiles, D]
        X_list.append(arr.mean(axis=0))  # mean over tiles → 512-D
        y_list.append(labels_by_key[k])
        sid_list.append(sid_by_key[k])
        key_list.append(k)
    X = np.stack(X_list, axis=0) if X_list else np.empty((0, 1))
    y = np.asarray(y_list, dtype=np.int64)
    return X, y, sid_list, key_list


# =========================
# Subject helpers
# =========================
def majority_vote(int_list: List[int]):
    if not int_list:
        return None
    z = int_list.count(0)
    o = int_list.count(1)
    return 1 if o > z else 0


def subject_labels_from_items(items_all):
    sid2lab = {}
    for _fp, lab, _d, sid in items_all:
        if sid in sid2lab:
            assert sid2lab[sid] == lab, f"Subject {sid} has mixed labels!"
        else:
            sid2lab[sid] = lab
    return sid2lab


# =========================
# Train one draw (tiles), then extract features and fit WINNER clf
# =========================
def train_one_draw_and_eval(
    train_items, test_items, draw_name, fold_idx, device, feat_mode=FEAT_MODE
):
    train_sids = {sid for _fp, _lab, _d, sid in train_items}
    test_sids = {sid for _fp, _lab, _d, sid in test_items}
    assert train_sids.isdisjoint(test_sids), "Leak: TRAIN and TEST share subjects!"

    reseed_for_fold(draw_name, fold_idx)

    ep = EPOCHS_FN[draw_name]
    lr = LR_INIT[draw_name]
    bs = BATCH_SIZE[draw_name]
    ls = LS_EPS[draw_name]
    wd = WEIGHT_DECAY[draw_name]
    hp_tag = f"ep{ep}_lr{lr:.4g}_bs{bs}_ls{ls}_wd{wd}"

    dl_tr = _make_loader(
        TrainTilesAugFirstDataset(train_items),
        shuffle=True,
        num_workers=NUM_WORKERS,
        base_seed=SEED,
        key=f"TILE-TRAIN|{draw_name}|fold{fold_idx}|{hp_tag}",
        batch_size=BATCH_SIZE[draw_name],
    )

    feat_mode_per_draw = "both" if draw_name == "spiral" else "resnet"

    # Fine-tune tile model (same as original settings)
    model = make_backbone_model(
        mode=feat_mode_per_draw,
        hidden1=128,
        hidden2=None,
        dropout=0.0,
        freeze_backbones=False,
        resnet_pretrained=True,
        pvt_pretrained=(feat_mode_per_draw == "both"),  # enable PVT weights for spiral
    ).to(device)

    opt = torch.optim.AdamW(
        model.parameters(), lr=LR_INIT[draw_name], weight_decay=WEIGHT_DECAY[draw_name]
    )
    sched = torch.optim.lr_scheduler.StepLR(opt, step_size=7, gamma=0.1)
    crit = nn.CrossEntropyLoss(label_smoothing=LS_EPS[draw_name])

    for ep in range(1, EPOCHS_FN[draw_name] + 1):
        model.train()
        corr = tot = 0
        for xb, yb in dl_tr:
            xb, yb = xb.to(device, non_blocking=True), torch.as_tensor(
                yb, device=device
            )
            opt.zero_grad(set_to_none=True)
            logits = model(xb)
            loss = crit(logits, yb)
            loss.backward()
            opt.step()
            corr += (logits.argmax(1) == yb).sum().item()
            tot += yb.numel()
        print(
            f"[{draw_name:7s}][Fold {fold_idx:02d}][Ep {ep:02d}] "
            f"train_tile_acc={corr/max(1,tot):.3f} | lr={opt.param_groups[0]['lr']:.6f}"
        )
        sched.step()

    # Save backbone (optional)
    (OUTDIR / draw_name).mkdir(parents=True, exist_ok=True)
    torch.save(
        model.state_dict(), OUTDIR / draw_name / f"WINS_{draw_name}_fold{fold_idx}.pth"
    )

    # ---- Extract per-image features
    Xtr, ytr, _sid_tr, _keys_tr = collect_image_features(model, train_items, device)
    Xte, yte, sid_te, _keys_te = collect_image_features(model, test_items, device)
    print(
        f"[{draw_name:7s}][Fold {fold_idx:02d}] Feature dim: {Xtr.shape[1]}  (Xtr={Xtr.shape}, Xte={Xte.shape})"
    )

    # ---- Fit WINNER classifier (fixed params)
    clf = WINNERS[draw_name]
    clf.fit(Xtr, ytr)
    yhat = clf.predict(Xte)

    # ---- Per-draw image metrics
    tp = int(((yhat == 1) & (yte == 1)).sum())
    fp = int(((yhat == 1) & (yte == 0)).sum())
    tn = int(((yhat == 0) & (yte == 0)).sum())
    fn = int(((yhat == 0) & (yte == 1)).sum())
    acc = (tp + tn) / max(1, (tp + fp + tn + fn))
    P, R, F1 = _prf(tp, fp, fn)
    print(
        f"[{draw_name:7s}][Fold {fold_idx:02d}] WINNER TEST (image): acc={acc:.3f}  prec={P:.3f}  recall={R:.3f}  f1={F1:.3f}  "
        f"[tp={tp} fp={fp} tn={tn} fn={fn}]"
    )

    # package predictions per image with sid for subject voting
    per_image = [
        (sid, int(p), int(t)) for sid, p, t in zip(sid_te, yhat.tolist(), yte.tolist())
    ]
    return per_image, {"tp": tp, "fp": fp, "tn": tn, "fn": fn}


# =========================
# 5-fold driver (subject-wise) with WINNERS
# =========================
def run_subjectwise_loso_winners(items_all, device, seed=42, feat_mode=FEAT_MODE):
    sid2lab = subject_labels_from_items(items_all)
    subjects = sorted(sid2lab.keys())
    y_subject = np.array([sid2lab[s] for s in subjects], dtype=int)

    # ---------- MICRO accumulators (pooled) ----------
    per_draw_counts_global = {d: {"tp": 0, "fp": 0, "tn": 0, "fn": 0} for d in DRAW_TYPES}
    per_draw_tp = {d: 0 for d in DRAW_TYPES}
    per_draw_tot = {d: 0 for d in DRAW_TYPES}

    subj_flat_counts_global = {"tp": 0, "fp": 0, "tn": 0, "fn": 0}
    subj_group_counts_global = {"tp": 0, "fp": 0, "tn": 0, "fn": 0}
    subj_flat_tp = subj_flat_tot = subj_group_tp = subj_group_tot = 0

    # ---------- MACRO accumulators ----------
    per_draw_fold_accs = {d: [] for d in DRAW_TYPES}  # image-level acc per LOSO run
    subj_flat_macro_accs = []   # subject-level flat acc per LOSO run (0/1 averaged)
    subj_group_macro_accs = []  # subject-level group acc per LOSO run (0/1 averaged)

    for fidx, test_sid in enumerate(subjects, 1):
        print("\n" + "#" * 80)
        print(f"############## SUBJECT-WISE LOSO — TEST {test_sid} (RUN {fidx:02d}) ##############")
        print("#" * 80 + "\n")

        train_sids = set(subjects) - {test_sid}
        test_sids = {test_sid}

        per_draw_items = {}
        for d in DRAW_TYPES:
            tr_items = [it for it in items_all if it[2] == d and it[3] in train_sids]
            te_items = [it for it in items_all if it[2] == d and it[3] in test_sids]
            per_draw_items[d] = (tr_items, te_items)

        fold_preds_by_draw = {d: [] for d in DRAW_TYPES}  # (sid, pred, true)

        # ----- Train/eval each draw with its fixed best classifier
        for d in DRAW_TYPES:
            tr_items, te_items = per_draw_items[d]
            # need both classes in training and at least one test image for this draw
            if len({lab for _fp, lab, _dr, _sid in tr_items}) < 2 or len(te_items) == 0:
                print(f"[{d:7s}][Run {fidx:02d}] Skipped (class collapse or empty test).")
                continue

            preds, counts = train_one_draw_and_eval(
                tr_items, te_items, d, fidx, device, feat_mode=feat_mode
            )
            fold_preds_by_draw[d].extend(preds)

            # ---- MICRO pooled image counts
            per_draw_counts_global[d]["tp"] += counts["tp"]
            per_draw_counts_global[d]["fp"] += counts["fp"]
            per_draw_counts_global[d]["tn"] += counts["tn"]
            per_draw_counts_global[d]["fn"] += counts["fn"]
            per_draw_tp[d] += counts["tp"] + counts["tn"]
            per_draw_tot[d] += counts["tp"] + counts["tn"] + counts["fp"] + counts["fn"]

            # ---- MACRO: per-run image accuracy for this draw
            _tot = counts["tp"] + counts["fp"] + counts["tn"] + counts["fn"]
            if _tot > 0:
                per_draw_fold_accs[d].append((counts["tp"] + counts["tn"]) / _tot)

        # ----- Subject-level voting for THIS held-out subject
        preds_by_sid_all = defaultdict(list)
        preds_by_sid_by_draw = defaultdict(lambda: defaultdict(list))
        for d in DRAW_TYPES:
            for sid, pred, true in fold_preds_by_draw[d]:
                preds_by_sid_all[sid].append(pred)
                preds_by_sid_by_draw[sid][d].append(pred)

        # Only one subject here
        sid = test_sid
        true_lab = sid2lab[sid]

        # flat-majority across all images (all draws pooled)
        flat_pred = None
        if len(preds_by_sid_all[sid]) > 0:
            zeros = preds_by_sid_all[sid].count(0)
            ones = len(preds_by_sid_all[sid]) - zeros
            flat_pred = 1 if ones > zeros else 0
            correct = int(flat_pred == true_lab)
            subj_flat_macro_accs.append(correct)  # for MACRO
            subj_flat_tp += correct               # for MICRO
            subj_flat_tot += 1
            if flat_pred == 1 and true_lab == 1:
                subj_flat_counts_global["tp"] += 1
            elif flat_pred == 1 and true_lab == 0:
                subj_flat_counts_global["fp"] += 1
            elif flat_pred == 0 and true_lab == 0:
                subj_flat_counts_global["tn"] += 1
            else:
                subj_flat_counts_global["fn"] += 1

        # group-majority (majority inside each draw → majority across draws)
        group_pred = None
        draw_votes = []
        for d in DRAW_TYPES:
            lst = preds_by_sid_by_draw[sid][d]
            if len(lst) > 0:
                z = lst.count(0)
                o = len(lst) - z
                draw_votes.append(1 if o > z else 0)
        if len(draw_votes) > 0:
            z = draw_votes.count(0)
            o = len(draw_votes) - z
            group_pred = 1 if o > z else 0
            correct = int(group_pred == true_lab)
            subj_group_macro_accs.append(correct)  # for MACRO
            subj_group_tp += correct               # for MICRO
            subj_group_tot += 1
            if group_pred == 1 and true_lab == 1:
                subj_group_counts_global["tp"] += 1
            elif group_pred == 1 and true_lab == 0:
                subj_group_counts_global["fp"] += 1
            elif group_pred == 0 and true_lab == 0:
                subj_group_counts_global["tn"] += 1
            else:
                subj_group_counts_global["fn"] += 1

        # Per-run subject report
        if flat_pred is not None:
            print(f"\n--- SUBJECT-LEVEL (Flat) — {sid} (Run {fidx:02d}) ---")
            print(f"pred={flat_pred} true={true_lab} correct={int(flat_pred==true_lab)}")
        if group_pred is not None:
            print(f"\n--- SUBJECT-LEVEL (Group) — {sid} (Run {fidx:02d}) ---")
            print(f"pred={group_pred} true={true_lab} correct={int(group_pred==true_lab)}")

    # ================= FINAL REPORTS =================
    # ---- PER-DRAW IMAGE ACCURACIES — MACRO
    print("\n=== PER-DRAW IMAGE ACCURACIES — WINNERS (MACRO over LOSO runs) ===")
    for d in DRAW_TYPES:
        if per_draw_fold_accs[d]:
            macro_acc = float(np.mean(per_draw_fold_accs[d]))
            print(f"{d:8s}: macro_img_acc={macro_acc:.4f}  (from {len(per_draw_fold_accs[d])} runs)")
        else:
            print(f"{d:8s}: n/a (no valid runs)")

    # ---- PER-DRAW IMAGE ACCURACIES — MICRO (pooled)
    print("\n=== PER-DRAW IMAGE ACCURACIES — WINNERS (MICRO pooled) ===")
    for d in DRAW_TYPES:
        if per_draw_tot[d] == 0:
            print(f"{d:8s}: n/a (no valid runs)")
        else:
            print(f"{d:8s}: micro_img_acc={per_draw_tp[d]/per_draw_tot[d]:.4f}  [{per_draw_tp[d]}/{per_draw_tot[d]}]")

    # ---- PER-DRAW IMAGE PRF — MICRO (pooled)
    print("\n=== PER-DRAW IMAGE PRF — WINNERS (MICRO pooled) ===")
    for d in DRAW_TYPES:
        c = per_draw_counts_global[d]
        if sum(c.values()) == 0:
            print(f"{d:8s}: n/a")
            continue
        P, R, F1 = _prf(c["tp"], c["fp"], c["fn"])
        acc = (c["tp"] + c["tn"]) / max(1, (c["tp"] + c["fp"] + c["tn"] + c["fn"]))
        print(f"{d:8s}: acc={acc:.3f}  prec={P:.3f}  recall={R:.3f}  f1={F1:.3f}  [tp={c['tp']} fp={c['fp']} tn={c['tn']} fn={c['fn']}]")

    # ---- SUBJECT-LEVEL ACCURACIES — MACRO
    print("\n=== SUBJECT-LEVEL ACCURACIES — WINNERS (MACRO over LOSO runs) ===")
    if subj_flat_macro_accs:
        print(f"Flat-majority (macro):   {float(np.mean(subj_flat_macro_accs)):.4f}")
    else:
        print("Flat-majority (macro):   n/a")
    if subj_group_macro_accs:
        print(f"Group-majority (macro):  {float(np.mean(subj_group_macro_accs)):.4f}")
    else:
        print("Group-majority (macro):  n/a")

    # ---- SUBJECT-LEVEL ACCURACIES — MICRO (pooled)
    flat_acc = subj_flat_tp / max(1, subj_flat_tot)
    group_acc = subj_group_tp / max(1, subj_group_tot)
    print("\n=== SUBJECT-LEVEL ACCURACIES — WINNERS (MICRO pooled) ===")
    print(f"Flat-majority (micro):   {flat_acc:.4f}  [{subj_flat_tp}/{subj_flat_tot}]")
    print(f"Group-majority (micro):  {group_acc:.4f}  [{subj_group_tp}/{subj_group_tot}]")

    # ---- SUBJECT-LEVEL PRF — MICRO (pooled)
    print("\n=== SUBJECT-LEVEL PRF — WINNERS (MICRO pooled) ===")
    c = subj_flat_counts_global
    P, R, F1 = _prf(c["tp"], c["fp"], c["fn"])
    acc = (c["tp"] + c["tn"]) / max(1, (c["tp"] + c["fp"] + c["tn"] + c["fn"]))
    print(f"Flat-majority:  acc={acc:.3f}  prec={P:.3f}  recall={R:.3f}  f1={F1:.3f}  [tp={c['tp']} fp={c['fp']} tn={c['tn']} fn={c['fn']}]")

    c = subj_group_counts_global
    P, R, F1 = _prf(c["tp"], c["fp"], c["fn"])
    acc = (c["tp"] + c["tn"]) / max(1, (c["tp"] + c["fp"] + c["tn"] + c["fn"]))
    print(f"Group-majority: acc={acc:.3f}  prec={P:.3f}  recall={R:.3f}  f1={F1:.3f}  [tp={c['tp']} fp={c['fp']} tn={c['tn']} fn={c['fn']}]")


# =========================
# Kickoff
# =========================
if __name__ == "__main__":
    OUTDIR.mkdir(parents=True, exist_ok=True)
    items_all = discover_items_tree(DATA_ROOT)
    results = run_subjectwise_loso_winners(
        items_all, device, seed=SEED, feat_mode=FEAT_MODE
    )
# Out:
# Using device: cuda
# [info] Found 594 images
#   by label    : Counter({0: 306, 1: 288})
#   by draw type: Counter({'meander': 264, 'spiral': 264, 'circle': 66})
#   subjects    : 66
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H1 (RUN 01) ##############
# ################################################################################
#
# [circle ][Fold 01][Ep 01] train_tile_acc=0.844 | lr=0.000316
# [circle ][Fold 01][Ep 02] train_tile_acc=0.924 | lr=0.000316
# [circle ][Fold 01][Ep 03] train_tile_acc=0.976 | lr=0.000316
# [circle ][Fold 01][Ep 04] train_tile_acc=0.973 | lr=0.000316
# [circle ][Fold 01][Ep 05] train_tile_acc=0.988 | lr=0.000316
# [circle ][Fold 01] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 01] WINNER TEST (image): acc=0.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=1 tn=0 fn=0]
# [meander][Fold 01][Ep 01] train_tile_acc=0.872 | lr=0.001000
# [meander][Fold 01][Ep 02] train_tile_acc=0.907 | lr=0.001000
# [meander][Fold 01][Ep 03] train_tile_acc=0.936 | lr=0.001000
# [meander][Fold 01][Ep 04] train_tile_acc=0.940 | lr=0.001000
# [meander][Fold 01][Ep 05] train_tile_acc=0.954 | lr=0.001000
# [meander][Fold 01][Ep 06] train_tile_acc=0.959 | lr=0.001000
# [meander][Fold 01][Ep 07] train_tile_acc=0.966 | lr=0.001000
# [meander][Fold 01][Ep 08] train_tile_acc=0.986 | lr=0.000100
# [meander][Fold 01][Ep 09] train_tile_acc=0.991 | lr=0.000100
# [meander][Fold 01][Ep 10] train_tile_acc=0.992 | lr=0.000100
# [meander][Fold 01] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 01] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 01][Ep 01] train_tile_acc=0.852 | lr=0.000316
# [spiral ][Fold 01][Ep 02] train_tile_acc=0.923 | lr=0.000316
# [spiral ][Fold 01][Ep 03] train_tile_acc=0.944 | lr=0.000316
# [spiral ][Fold 01][Ep 04] train_tile_acc=0.965 | lr=0.000316
# [spiral ][Fold 01][Ep 05] train_tile_acc=0.975 | lr=0.000316
# [spiral ][Fold 01] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 01] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H1 (Run 01) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H1 (Run 01) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H10 (RUN 02) ##############
# ################################################################################
#
# [circle ][Fold 02][Ep 01] train_tile_acc=0.840 | lr=0.000316
# [circle ][Fold 02][Ep 02] train_tile_acc=0.933 | lr=0.000316
# [circle ][Fold 02][Ep 03] train_tile_acc=0.964 | lr=0.000316
# [circle ][Fold 02][Ep 04] train_tile_acc=0.975 | lr=0.000316
# [circle ][Fold 02][Ep 05] train_tile_acc=0.992 | lr=0.000316
# [circle ][Fold 02] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 02] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 02][Ep 01] train_tile_acc=0.866 | lr=0.001000
# [meander][Fold 02][Ep 02] train_tile_acc=0.915 | lr=0.001000
# [meander][Fold 02][Ep 03] train_tile_acc=0.927 | lr=0.001000
# [meander][Fold 02][Ep 04] train_tile_acc=0.941 | lr=0.001000
# [meander][Fold 02][Ep 05] train_tile_acc=0.950 | lr=0.001000
# [meander][Fold 02][Ep 06] train_tile_acc=0.964 | lr=0.001000
# [meander][Fold 02][Ep 07] train_tile_acc=0.966 | lr=0.001000
# [meander][Fold 02][Ep 08] train_tile_acc=0.982 | lr=0.000100
# [meander][Fold 02][Ep 09] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 02][Ep 10] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 02] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 02] WINNER TEST (image): acc=0.500  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=2 tn=2 fn=0]
# [spiral ][Fold 02][Ep 01] train_tile_acc=0.843 | lr=0.000316
# [spiral ][Fold 02][Ep 02] train_tile_acc=0.926 | lr=0.000316
# [spiral ][Fold 02][Ep 03] train_tile_acc=0.947 | lr=0.000316
# [spiral ][Fold 02][Ep 04] train_tile_acc=0.959 | lr=0.000316
# [spiral ][Fold 02][Ep 05] train_tile_acc=0.977 | lr=0.000316
# [spiral ][Fold 02] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 02] WINNER TEST (image): acc=0.750  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=1 tn=3 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H10 (Run 02) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H10 (Run 02) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H11 (RUN 03) ##############
# ################################################################################
#
# [circle ][Fold 03][Ep 01] train_tile_acc=0.846 | lr=0.000316
# [circle ][Fold 03][Ep 02] train_tile_acc=0.942 | lr=0.000316
# [circle ][Fold 03][Ep 03] train_tile_acc=0.978 | lr=0.000316
# [circle ][Fold 03][Ep 04] train_tile_acc=0.990 | lr=0.000316
# [circle ][Fold 03][Ep 05] train_tile_acc=0.980 | lr=0.000316
# [circle ][Fold 03] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 03] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 03][Ep 01] train_tile_acc=0.866 | lr=0.001000
# [meander][Fold 03][Ep 02] train_tile_acc=0.914 | lr=0.001000
# [meander][Fold 03][Ep 03] train_tile_acc=0.929 | lr=0.001000
# [meander][Fold 03][Ep 04] train_tile_acc=0.941 | lr=0.001000
# [meander][Fold 03][Ep 05] train_tile_acc=0.943 | lr=0.001000
# [meander][Fold 03][Ep 06] train_tile_acc=0.955 | lr=0.001000
# [meander][Fold 03][Ep 07] train_tile_acc=0.961 | lr=0.001000
# [meander][Fold 03][Ep 08] train_tile_acc=0.979 | lr=0.000100
# [meander][Fold 03][Ep 09] train_tile_acc=0.990 | lr=0.000100
# [meander][Fold 03][Ep 10] train_tile_acc=0.995 | lr=0.000100
# [meander][Fold 03] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 03] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 03][Ep 01] train_tile_acc=0.849 | lr=0.000316
# [spiral ][Fold 03][Ep 02] train_tile_acc=0.921 | lr=0.000316
# [spiral ][Fold 03][Ep 03] train_tile_acc=0.950 | lr=0.000316
# [spiral ][Fold 03][Ep 04] train_tile_acc=0.966 | lr=0.000316
# [spiral ][Fold 03][Ep 05] train_tile_acc=0.976 | lr=0.000316
# [spiral ][Fold 03] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 03] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H11 (Run 03) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H11 (Run 03) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H12 (RUN 04) ##############
# ################################################################################
#
# [circle ][Fold 04][Ep 01] train_tile_acc=0.834 | lr=0.000316
# [circle ][Fold 04][Ep 02] train_tile_acc=0.933 | lr=0.000316
# [circle ][Fold 04][Ep 03] train_tile_acc=0.963 | lr=0.000316
# [circle ][Fold 04][Ep 04] train_tile_acc=0.989 | lr=0.000316
# [circle ][Fold 04][Ep 05] train_tile_acc=0.994 | lr=0.000316
# [circle ][Fold 04] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 04] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 04][Ep 01] train_tile_acc=0.844 | lr=0.001000
# [meander][Fold 04][Ep 02] train_tile_acc=0.908 | lr=0.001000
# [meander][Fold 04][Ep 03] train_tile_acc=0.927 | lr=0.001000
# [meander][Fold 04][Ep 04] train_tile_acc=0.930 | lr=0.001000
# [meander][Fold 04][Ep 05] train_tile_acc=0.961 | lr=0.001000
# [meander][Fold 04][Ep 06] train_tile_acc=0.958 | lr=0.001000
# [meander][Fold 04][Ep 07] train_tile_acc=0.962 | lr=0.001000
# [meander][Fold 04][Ep 08] train_tile_acc=0.984 | lr=0.000100
# [meander][Fold 04][Ep 09] train_tile_acc=0.992 | lr=0.000100
# [meander][Fold 04][Ep 10] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 04] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 04] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 04][Ep 01] train_tile_acc=0.825 | lr=0.000316
# [spiral ][Fold 04][Ep 02] train_tile_acc=0.924 | lr=0.000316
# [spiral ][Fold 04][Ep 03] train_tile_acc=0.954 | lr=0.000316
# [spiral ][Fold 04][Ep 04] train_tile_acc=0.966 | lr=0.000316
# [spiral ][Fold 04][Ep 05] train_tile_acc=0.984 | lr=0.000316
# [spiral ][Fold 04] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 04] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H12 (Run 04) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H12 (Run 04) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H13 (RUN 05) ##############
# ################################################################################
#
# [circle ][Fold 05][Ep 01] train_tile_acc=0.841 | lr=0.000316
# [circle ][Fold 05][Ep 02] train_tile_acc=0.938 | lr=0.000316
# [circle ][Fold 05][Ep 03] train_tile_acc=0.969 | lr=0.000316
# [circle ][Fold 05][Ep 04] train_tile_acc=0.983 | lr=0.000316
# [circle ][Fold 05][Ep 05] train_tile_acc=0.976 | lr=0.000316
# [circle ][Fold 05] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 05] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 05][Ep 01] train_tile_acc=0.867 | lr=0.001000
# [meander][Fold 05][Ep 02] train_tile_acc=0.911 | lr=0.001000
# [meander][Fold 05][Ep 03] train_tile_acc=0.918 | lr=0.001000
# [meander][Fold 05][Ep 04] train_tile_acc=0.939 | lr=0.001000
# [meander][Fold 05][Ep 05] train_tile_acc=0.951 | lr=0.001000
# [meander][Fold 05][Ep 06] train_tile_acc=0.967 | lr=0.001000
# [meander][Fold 05][Ep 07] train_tile_acc=0.959 | lr=0.001000
# [meander][Fold 05][Ep 08] train_tile_acc=0.981 | lr=0.000100
# [meander][Fold 05][Ep 09] train_tile_acc=0.998 | lr=0.000100
# [meander][Fold 05][Ep 10] train_tile_acc=0.993 | lr=0.000100
# [meander][Fold 05] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 05] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 05][Ep 01] train_tile_acc=0.842 | lr=0.000316
# [spiral ][Fold 05][Ep 02] train_tile_acc=0.921 | lr=0.000316
# [spiral ][Fold 05][Ep 03] train_tile_acc=0.950 | lr=0.000316
# [spiral ][Fold 05][Ep 04] train_tile_acc=0.974 | lr=0.000316
# [spiral ][Fold 05][Ep 05] train_tile_acc=0.972 | lr=0.000316
# [spiral ][Fold 05] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 05] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H13 (Run 05) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H13 (Run 05) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H14 (RUN 06) ##############
# ################################################################################
#
# [circle ][Fold 06][Ep 01] train_tile_acc=0.861 | lr=0.000316
# [circle ][Fold 06][Ep 02] train_tile_acc=0.943 | lr=0.000316
# [circle ][Fold 06][Ep 03] train_tile_acc=0.984 | lr=0.000316
# [circle ][Fold 06][Ep 04] train_tile_acc=0.994 | lr=0.000316
# [circle ][Fold 06][Ep 05] train_tile_acc=1.000 | lr=0.000316
# [circle ][Fold 06] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 06] WINNER TEST (image): acc=0.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=1 tn=0 fn=0]
# [meander][Fold 06][Ep 01] train_tile_acc=0.864 | lr=0.001000
# [meander][Fold 06][Ep 02] train_tile_acc=0.896 | lr=0.001000
# [meander][Fold 06][Ep 03] train_tile_acc=0.915 | lr=0.001000
# [meander][Fold 06][Ep 04] train_tile_acc=0.942 | lr=0.001000
# [meander][Fold 06][Ep 05] train_tile_acc=0.952 | lr=0.001000
# [meander][Fold 06][Ep 06] train_tile_acc=0.966 | lr=0.001000
# [meander][Fold 06][Ep 07] train_tile_acc=0.962 | lr=0.001000
# [meander][Fold 06][Ep 08] train_tile_acc=0.983 | lr=0.000100
# [meander][Fold 06][Ep 09] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 06][Ep 10] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 06] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 06] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 06][Ep 01] train_tile_acc=0.860 | lr=0.000316
# [spiral ][Fold 06][Ep 02] train_tile_acc=0.932 | lr=0.000316
# [spiral ][Fold 06][Ep 03] train_tile_acc=0.959 | lr=0.000316
# [spiral ][Fold 06][Ep 04] train_tile_acc=0.970 | lr=0.000316
# [spiral ][Fold 06][Ep 05] train_tile_acc=0.977 | lr=0.000316
# [spiral ][Fold 06] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 06] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H14 (Run 06) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H14 (Run 06) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H16 (RUN 07) ##############
# ################################################################################
#
# [circle ][Fold 07][Ep 01] train_tile_acc=0.835 | lr=0.000316
# [circle ][Fold 07][Ep 02] train_tile_acc=0.925 | lr=0.000316
# [circle ][Fold 07][Ep 03] train_tile_acc=0.981 | lr=0.000316
# [circle ][Fold 07][Ep 04] train_tile_acc=0.968 | lr=0.000316
# [circle ][Fold 07][Ep 05] train_tile_acc=0.985 | lr=0.000316
# [circle ][Fold 07] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 07] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 07][Ep 01] train_tile_acc=0.848 | lr=0.001000
# [meander][Fold 07][Ep 02] train_tile_acc=0.917 | lr=0.001000
# [meander][Fold 07][Ep 03] train_tile_acc=0.925 | lr=0.001000
# [meander][Fold 07][Ep 04] train_tile_acc=0.943 | lr=0.001000
# [meander][Fold 07][Ep 05] train_tile_acc=0.949 | lr=0.001000
# [meander][Fold 07][Ep 06] train_tile_acc=0.957 | lr=0.001000
# [meander][Fold 07][Ep 07] train_tile_acc=0.963 | lr=0.001000
# [meander][Fold 07][Ep 08] train_tile_acc=0.979 | lr=0.000100
# [meander][Fold 07][Ep 09] train_tile_acc=0.992 | lr=0.000100
# [meander][Fold 07][Ep 10] train_tile_acc=0.995 | lr=0.000100
# [meander][Fold 07] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 07] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 07][Ep 01] train_tile_acc=0.874 | lr=0.000316
# [spiral ][Fold 07][Ep 02] train_tile_acc=0.931 | lr=0.000316
# [spiral ][Fold 07][Ep 03] train_tile_acc=0.948 | lr=0.000316
# [spiral ][Fold 07][Ep 04] train_tile_acc=0.954 | lr=0.000316
# [spiral ][Fold 07][Ep 05] train_tile_acc=0.973 | lr=0.000316
# [spiral ][Fold 07] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 07] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H16 (Run 07) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H16 (Run 07) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H17 (RUN 08) ##############
# ################################################################################
#
# [circle ][Fold 08][Ep 01] train_tile_acc=0.827 | lr=0.000316
# [circle ][Fold 08][Ep 02] train_tile_acc=0.911 | lr=0.000316
# [circle ][Fold 08][Ep 03] train_tile_acc=0.966 | lr=0.000316
# [circle ][Fold 08][Ep 04] train_tile_acc=0.980 | lr=0.000316
# [circle ][Fold 08][Ep 05] train_tile_acc=0.994 | lr=0.000316
# [circle ][Fold 08] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 08] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 08][Ep 01] train_tile_acc=0.862 | lr=0.001000
# [meander][Fold 08][Ep 02] train_tile_acc=0.913 | lr=0.001000
# [meander][Fold 08][Ep 03] train_tile_acc=0.926 | lr=0.001000
# [meander][Fold 08][Ep 04] train_tile_acc=0.947 | lr=0.001000
# [meander][Fold 08][Ep 05] train_tile_acc=0.959 | lr=0.001000
# [meander][Fold 08][Ep 06] train_tile_acc=0.960 | lr=0.001000
# [meander][Fold 08][Ep 07] train_tile_acc=0.965 | lr=0.001000
# [meander][Fold 08][Ep 08] train_tile_acc=0.980 | lr=0.000100
# [meander][Fold 08][Ep 09] train_tile_acc=0.991 | lr=0.000100
# [meander][Fold 08][Ep 10] train_tile_acc=0.993 | lr=0.000100
# [meander][Fold 08] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 08] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 08][Ep 01] train_tile_acc=0.850 | lr=0.000316
# [spiral ][Fold 08][Ep 02] train_tile_acc=0.920 | lr=0.000316
# [spiral ][Fold 08][Ep 03] train_tile_acc=0.952 | lr=0.000316
# [spiral ][Fold 08][Ep 04] train_tile_acc=0.970 | lr=0.000316
# [spiral ][Fold 08][Ep 05] train_tile_acc=0.970 | lr=0.000316
# [spiral ][Fold 08] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 08] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H17 (Run 08) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H17 (Run 08) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H18 (RUN 09) ##############
# ################################################################################
#
# [circle ][Fold 09][Ep 01] train_tile_acc=0.825 | lr=0.000316
# [circle ][Fold 09][Ep 02] train_tile_acc=0.933 | lr=0.000316
# [circle ][Fold 09][Ep 03] train_tile_acc=0.959 | lr=0.000316
# [circle ][Fold 09][Ep 04] train_tile_acc=0.963 | lr=0.000316
# [circle ][Fold 09][Ep 05] train_tile_acc=0.974 | lr=0.000316
# [circle ][Fold 09] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 09] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 09][Ep 01] train_tile_acc=0.848 | lr=0.001000
# [meander][Fold 09][Ep 02] train_tile_acc=0.923 | lr=0.001000
# [meander][Fold 09][Ep 03] train_tile_acc=0.917 | lr=0.001000
# [meander][Fold 09][Ep 04] train_tile_acc=0.950 | lr=0.001000
# [meander][Fold 09][Ep 05] train_tile_acc=0.949 | lr=0.001000
# [meander][Fold 09][Ep 06] train_tile_acc=0.956 | lr=0.001000
# [meander][Fold 09][Ep 07] train_tile_acc=0.970 | lr=0.001000
# [meander][Fold 09][Ep 08] train_tile_acc=0.988 | lr=0.000100
# [meander][Fold 09][Ep 09] train_tile_acc=0.990 | lr=0.000100
# [meander][Fold 09][Ep 10] train_tile_acc=0.996 | lr=0.000100
# [meander][Fold 09] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 09] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 09][Ep 01] train_tile_acc=0.867 | lr=0.000316
# [spiral ][Fold 09][Ep 02] train_tile_acc=0.929 | lr=0.000316
# [spiral ][Fold 09][Ep 03] train_tile_acc=0.955 | lr=0.000316
# [spiral ][Fold 09][Ep 04] train_tile_acc=0.959 | lr=0.000316
# [spiral ][Fold 09][Ep 05] train_tile_acc=0.986 | lr=0.000316
# [spiral ][Fold 09] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 09] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H18 (Run 09) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H18 (Run 09) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H19 (RUN 10) ##############
# ################################################################################
#
# [circle ][Fold 10][Ep 01] train_tile_acc=0.815 | lr=0.000316
# [circle ][Fold 10][Ep 02] train_tile_acc=0.933 | lr=0.000316
# [circle ][Fold 10][Ep 03] train_tile_acc=0.970 | lr=0.000316
# [circle ][Fold 10][Ep 04] train_tile_acc=0.974 | lr=0.000316
# [circle ][Fold 10][Ep 05] train_tile_acc=0.954 | lr=0.000316
# [circle ][Fold 10] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 10] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 10][Ep 01] train_tile_acc=0.854 | lr=0.001000
# [meander][Fold 10][Ep 02] train_tile_acc=0.906 | lr=0.001000
# [meander][Fold 10][Ep 03] train_tile_acc=0.929 | lr=0.001000
# [meander][Fold 10][Ep 04] train_tile_acc=0.921 | lr=0.001000
# [meander][Fold 10][Ep 05] train_tile_acc=0.952 | lr=0.001000
# [meander][Fold 10][Ep 06] train_tile_acc=0.944 | lr=0.001000
# [meander][Fold 10][Ep 07] train_tile_acc=0.959 | lr=0.001000
# [meander][Fold 10][Ep 08] train_tile_acc=0.982 | lr=0.000100
# [meander][Fold 10][Ep 09] train_tile_acc=0.990 | lr=0.000100
# [meander][Fold 10][Ep 10] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 10] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 10] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 10][Ep 01] train_tile_acc=0.861 | lr=0.000316
# [spiral ][Fold 10][Ep 02] train_tile_acc=0.907 | lr=0.000316
# [spiral ][Fold 10][Ep 03] train_tile_acc=0.958 | lr=0.000316
# [spiral ][Fold 10][Ep 04] train_tile_acc=0.961 | lr=0.000316
# [spiral ][Fold 10][Ep 05] train_tile_acc=0.973 | lr=0.000316
# [spiral ][Fold 10] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 10] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H19 (Run 10) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H19 (Run 10) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H2 (RUN 11) ##############
# ################################################################################
#
# [circle ][Fold 11][Ep 01] train_tile_acc=0.834 | lr=0.000316
# [circle ][Fold 11][Ep 02] train_tile_acc=0.938 | lr=0.000316
# [circle ][Fold 11][Ep 03] train_tile_acc=0.975 | lr=0.000316
# [circle ][Fold 11][Ep 04] train_tile_acc=0.986 | lr=0.000316
# [circle ][Fold 11][Ep 05] train_tile_acc=0.980 | lr=0.000316
# [circle ][Fold 11] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 11] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 11][Ep 01] train_tile_acc=0.867 | lr=0.001000
# [meander][Fold 11][Ep 02] train_tile_acc=0.908 | lr=0.001000
# [meander][Fold 11][Ep 03] train_tile_acc=0.932 | lr=0.001000
# [meander][Fold 11][Ep 04] train_tile_acc=0.926 | lr=0.001000
# [meander][Fold 11][Ep 05] train_tile_acc=0.955 | lr=0.001000
# [meander][Fold 11][Ep 06] train_tile_acc=0.954 | lr=0.001000
# [meander][Fold 11][Ep 07] train_tile_acc=0.971 | lr=0.001000
# [meander][Fold 11][Ep 08] train_tile_acc=0.987 | lr=0.000100
# [meander][Fold 11][Ep 09] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 11][Ep 10] train_tile_acc=0.995 | lr=0.000100
# [meander][Fold 11] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 11] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 11][Ep 01] train_tile_acc=0.861 | lr=0.000316
# [spiral ][Fold 11][Ep 02] train_tile_acc=0.915 | lr=0.000316
# [spiral ][Fold 11][Ep 03] train_tile_acc=0.957 | lr=0.000316
# [spiral ][Fold 11][Ep 04] train_tile_acc=0.975 | lr=0.000316
# [spiral ][Fold 11][Ep 05] train_tile_acc=0.982 | lr=0.000316
# [spiral ][Fold 11] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 11] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H2 (Run 11) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H2 (Run 11) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H20 (RUN 12) ##############
# ################################################################################
#
# [circle ][Fold 12][Ep 01] train_tile_acc=0.827 | lr=0.000316
# [circle ][Fold 12][Ep 02] train_tile_acc=0.939 | lr=0.000316
# [circle ][Fold 12][Ep 03] train_tile_acc=0.964 | lr=0.000316
# [circle ][Fold 12][Ep 04] train_tile_acc=0.967 | lr=0.000316
# [circle ][Fold 12][Ep 05] train_tile_acc=0.991 | lr=0.000316
# [circle ][Fold 12] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 12] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 12][Ep 01] train_tile_acc=0.848 | lr=0.001000
# [meander][Fold 12][Ep 02] train_tile_acc=0.905 | lr=0.001000
# [meander][Fold 12][Ep 03] train_tile_acc=0.922 | lr=0.001000
# [meander][Fold 12][Ep 04] train_tile_acc=0.926 | lr=0.001000
# [meander][Fold 12][Ep 05] train_tile_acc=0.936 | lr=0.001000
# [meander][Fold 12][Ep 06] train_tile_acc=0.949 | lr=0.001000
# [meander][Fold 12][Ep 07] train_tile_acc=0.963 | lr=0.001000
# [meander][Fold 12][Ep 08] train_tile_acc=0.987 | lr=0.000100
# [meander][Fold 12][Ep 09] train_tile_acc=0.992 | lr=0.000100
# [meander][Fold 12][Ep 10] train_tile_acc=0.993 | lr=0.000100
# [meander][Fold 12] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 12] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 12][Ep 01] train_tile_acc=0.862 | lr=0.000316
# [spiral ][Fold 12][Ep 02] train_tile_acc=0.918 | lr=0.000316
# [spiral ][Fold 12][Ep 03] train_tile_acc=0.952 | lr=0.000316
# [spiral ][Fold 12][Ep 04] train_tile_acc=0.969 | lr=0.000316
# [spiral ][Fold 12][Ep 05] train_tile_acc=0.975 | lr=0.000316
# [spiral ][Fold 12] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 12] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H20 (Run 12) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H20 (Run 12) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H21 (RUN 13) ##############
# ################################################################################
#
# [circle ][Fold 13][Ep 01] train_tile_acc=0.816 | lr=0.000316
# [circle ][Fold 13][Ep 02] train_tile_acc=0.910 | lr=0.000316
# [circle ][Fold 13][Ep 03] train_tile_acc=0.961 | lr=0.000316
# [circle ][Fold 13][Ep 04] train_tile_acc=0.991 | lr=0.000316
# [circle ][Fold 13][Ep 05] train_tile_acc=0.982 | lr=0.000316
# [circle ][Fold 13] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 13] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 13][Ep 01] train_tile_acc=0.875 | lr=0.001000
# [meander][Fold 13][Ep 02] train_tile_acc=0.911 | lr=0.001000
# [meander][Fold 13][Ep 03] train_tile_acc=0.925 | lr=0.001000
# [meander][Fold 13][Ep 04] train_tile_acc=0.942 | lr=0.001000
# [meander][Fold 13][Ep 05] train_tile_acc=0.942 | lr=0.001000
# [meander][Fold 13][Ep 06] train_tile_acc=0.968 | lr=0.001000
# [meander][Fold 13][Ep 07] train_tile_acc=0.969 | lr=0.001000
# [meander][Fold 13][Ep 08] train_tile_acc=0.982 | lr=0.000100
# [meander][Fold 13][Ep 09] train_tile_acc=0.993 | lr=0.000100
# [meander][Fold 13][Ep 10] train_tile_acc=0.996 | lr=0.000100
# [meander][Fold 13] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 13] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 13][Ep 01] train_tile_acc=0.844 | lr=0.000316
# [spiral ][Fold 13][Ep 02] train_tile_acc=0.917 | lr=0.000316
# [spiral ][Fold 13][Ep 03] train_tile_acc=0.955 | lr=0.000316
# [spiral ][Fold 13][Ep 04] train_tile_acc=0.960 | lr=0.000316
# [spiral ][Fold 13][Ep 05] train_tile_acc=0.978 | lr=0.000316
# [spiral ][Fold 13] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 13] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H21 (Run 13) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H21 (Run 13) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H22 (RUN 14) ##############
# ################################################################################
#
# [circle ][Fold 14][Ep 01] train_tile_acc=0.815 | lr=0.000316
# [circle ][Fold 14][Ep 02] train_tile_acc=0.926 | lr=0.000316
# [circle ][Fold 14][Ep 03] train_tile_acc=0.977 | lr=0.000316
# [circle ][Fold 14][Ep 04] train_tile_acc=0.984 | lr=0.000316
# [circle ][Fold 14][Ep 05] train_tile_acc=0.995 | lr=0.000316
# [circle ][Fold 14] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 14] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 14][Ep 01] train_tile_acc=0.864 | lr=0.001000
# [meander][Fold 14][Ep 02] train_tile_acc=0.918 | lr=0.001000
# [meander][Fold 14][Ep 03] train_tile_acc=0.925 | lr=0.001000
# [meander][Fold 14][Ep 04] train_tile_acc=0.936 | lr=0.001000
# [meander][Fold 14][Ep 05] train_tile_acc=0.958 | lr=0.001000
# [meander][Fold 14][Ep 06] train_tile_acc=0.963 | lr=0.001000
# [meander][Fold 14][Ep 07] train_tile_acc=0.972 | lr=0.001000
# [meander][Fold 14][Ep 08] train_tile_acc=0.989 | lr=0.000100
# [meander][Fold 14][Ep 09] train_tile_acc=0.991 | lr=0.000100
# [meander][Fold 14][Ep 10] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 14] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 14] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 14][Ep 01] train_tile_acc=0.849 | lr=0.000316
# [spiral ][Fold 14][Ep 02] train_tile_acc=0.917 | lr=0.000316
# [spiral ][Fold 14][Ep 03] train_tile_acc=0.944 | lr=0.000316
# [spiral ][Fold 14][Ep 04] train_tile_acc=0.963 | lr=0.000316
# [spiral ][Fold 14][Ep 05] train_tile_acc=0.971 | lr=0.000316
# [spiral ][Fold 14] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 14] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H22 (Run 14) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H22 (Run 14) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H23 (RUN 15) ##############
# ################################################################################
#
# [circle ][Fold 15][Ep 01] train_tile_acc=0.818 | lr=0.000316
# [circle ][Fold 15][Ep 02] train_tile_acc=0.925 | lr=0.000316
# [circle ][Fold 15][Ep 03] train_tile_acc=0.959 | lr=0.000316
# [circle ][Fold 15][Ep 04] train_tile_acc=0.983 | lr=0.000316
# [circle ][Fold 15][Ep 05] train_tile_acc=0.998 | lr=0.000316
# [circle ][Fold 15] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 15] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 15][Ep 01] train_tile_acc=0.841 | lr=0.001000
# [meander][Fold 15][Ep 02] train_tile_acc=0.912 | lr=0.001000
# [meander][Fold 15][Ep 03] train_tile_acc=0.917 | lr=0.001000
# [meander][Fold 15][Ep 04] train_tile_acc=0.940 | lr=0.001000
# [meander][Fold 15][Ep 05] train_tile_acc=0.953 | lr=0.001000
# [meander][Fold 15][Ep 06] train_tile_acc=0.960 | lr=0.001000
# [meander][Fold 15][Ep 07] train_tile_acc=0.964 | lr=0.001000
# [meander][Fold 15][Ep 08] train_tile_acc=0.991 | lr=0.000100
# [meander][Fold 15][Ep 09] train_tile_acc=0.995 | lr=0.000100
# [meander][Fold 15][Ep 10] train_tile_acc=0.996 | lr=0.000100
# [meander][Fold 15] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 15] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 15][Ep 01] train_tile_acc=0.816 | lr=0.000316
# [spiral ][Fold 15][Ep 02] train_tile_acc=0.912 | lr=0.000316
# [spiral ][Fold 15][Ep 03] train_tile_acc=0.955 | lr=0.000316
# [spiral ][Fold 15][Ep 04] train_tile_acc=0.966 | lr=0.000316
# [spiral ][Fold 15][Ep 05] train_tile_acc=0.968 | lr=0.000316
# [spiral ][Fold 15] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 15] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H23 (Run 15) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H23 (Run 15) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H24 (RUN 16) ##############
# ################################################################################
#
# [circle ][Fold 16][Ep 01] train_tile_acc=0.818 | lr=0.000316
# [circle ][Fold 16][Ep 02] train_tile_acc=0.924 | lr=0.000316
# [circle ][Fold 16][Ep 03] train_tile_acc=0.974 | lr=0.000316
# [circle ][Fold 16][Ep 04] train_tile_acc=0.972 | lr=0.000316
# [circle ][Fold 16][Ep 05] train_tile_acc=0.988 | lr=0.000316
# [circle ][Fold 16] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 16] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 16][Ep 01] train_tile_acc=0.853 | lr=0.001000
# [meander][Fold 16][Ep 02] train_tile_acc=0.904 | lr=0.001000
# [meander][Fold 16][Ep 03] train_tile_acc=0.936 | lr=0.001000
# [meander][Fold 16][Ep 04] train_tile_acc=0.946 | lr=0.001000
# [meander][Fold 16][Ep 05] train_tile_acc=0.959 | lr=0.001000
# [meander][Fold 16][Ep 06] train_tile_acc=0.966 | lr=0.001000
# [meander][Fold 16][Ep 07] train_tile_acc=0.959 | lr=0.001000
# [meander][Fold 16][Ep 08] train_tile_acc=0.981 | lr=0.000100
# [meander][Fold 16][Ep 09] train_tile_acc=0.992 | lr=0.000100
# [meander][Fold 16][Ep 10] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 16] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 16] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 16][Ep 01] train_tile_acc=0.859 | lr=0.000316
# [spiral ][Fold 16][Ep 02] train_tile_acc=0.928 | lr=0.000316
# [spiral ][Fold 16][Ep 03] train_tile_acc=0.946 | lr=0.000316
# [spiral ][Fold 16][Ep 04] train_tile_acc=0.968 | lr=0.000316
# [spiral ][Fold 16][Ep 05] train_tile_acc=0.984 | lr=0.000316
# [spiral ][Fold 16] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 16] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H24 (Run 16) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H24 (Run 16) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H26 (RUN 17) ##############
# ################################################################################
#
# [circle ][Fold 17][Ep 01] train_tile_acc=0.838 | lr=0.000316
# [circle ][Fold 17][Ep 02] train_tile_acc=0.938 | lr=0.000316
# [circle ][Fold 17][Ep 03] train_tile_acc=0.964 | lr=0.000316
# [circle ][Fold 17][Ep 04] train_tile_acc=0.988 | lr=0.000316
# [circle ][Fold 17][Ep 05] train_tile_acc=0.998 | lr=0.000316
# [circle ][Fold 17] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 17] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 17][Ep 01] train_tile_acc=0.846 | lr=0.001000
# [meander][Fold 17][Ep 02] train_tile_acc=0.905 | lr=0.001000
# [meander][Fold 17][Ep 03] train_tile_acc=0.914 | lr=0.001000
# [meander][Fold 17][Ep 04] train_tile_acc=0.932 | lr=0.001000
# [meander][Fold 17][Ep 05] train_tile_acc=0.939 | lr=0.001000
# [meander][Fold 17][Ep 06] train_tile_acc=0.952 | lr=0.001000
# [meander][Fold 17][Ep 07] train_tile_acc=0.955 | lr=0.001000
# [meander][Fold 17][Ep 08] train_tile_acc=0.982 | lr=0.000100
# [meander][Fold 17][Ep 09] train_tile_acc=0.985 | lr=0.000100
# [meander][Fold 17][Ep 10] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 17] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 17] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 17][Ep 01] train_tile_acc=0.862 | lr=0.000316
# [spiral ][Fold 17][Ep 02] train_tile_acc=0.934 | lr=0.000316
# [spiral ][Fold 17][Ep 03] train_tile_acc=0.953 | lr=0.000316
# [spiral ][Fold 17][Ep 04] train_tile_acc=0.971 | lr=0.000316
# [spiral ][Fold 17][Ep 05] train_tile_acc=0.979 | lr=0.000316
# [spiral ][Fold 17] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 17] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H26 (Run 17) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H26 (Run 17) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H27 (RUN 18) ##############
# ################################################################################
#
# [circle ][Fold 18][Ep 01] train_tile_acc=0.835 | lr=0.000316
# [circle ][Fold 18][Ep 02] train_tile_acc=0.911 | lr=0.000316
# [circle ][Fold 18][Ep 03] train_tile_acc=0.963 | lr=0.000316
# [circle ][Fold 18][Ep 04] train_tile_acc=0.979 | lr=0.000316
# [circle ][Fold 18][Ep 05] train_tile_acc=0.985 | lr=0.000316
# [circle ][Fold 18] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 18] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 18][Ep 01] train_tile_acc=0.868 | lr=0.001000
# [meander][Fold 18][Ep 02] train_tile_acc=0.900 | lr=0.001000
# [meander][Fold 18][Ep 03] train_tile_acc=0.928 | lr=0.001000
# [meander][Fold 18][Ep 04] train_tile_acc=0.938 | lr=0.001000
# [meander][Fold 18][Ep 05] train_tile_acc=0.944 | lr=0.001000
# [meander][Fold 18][Ep 06] train_tile_acc=0.955 | lr=0.001000
# [meander][Fold 18][Ep 07] train_tile_acc=0.968 | lr=0.001000
# [meander][Fold 18][Ep 08] train_tile_acc=0.976 | lr=0.000100
# [meander][Fold 18][Ep 09] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 18][Ep 10] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 18] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 18] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 18][Ep 01] train_tile_acc=0.862 | lr=0.000316
# [spiral ][Fold 18][Ep 02] train_tile_acc=0.930 | lr=0.000316
# [spiral ][Fold 18][Ep 03] train_tile_acc=0.947 | lr=0.000316
# [spiral ][Fold 18][Ep 04] train_tile_acc=0.966 | lr=0.000316
# [spiral ][Fold 18][Ep 05] train_tile_acc=0.982 | lr=0.000316
# [spiral ][Fold 18] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 18] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H27 (Run 18) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H27 (Run 18) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H28 (RUN 19) ##############
# ################################################################################
#
# [circle ][Fold 19][Ep 01] train_tile_acc=0.833 | lr=0.000316
# [circle ][Fold 19][Ep 02] train_tile_acc=0.929 | lr=0.000316
# [circle ][Fold 19][Ep 03] train_tile_acc=0.975 | lr=0.000316
# [circle ][Fold 19][Ep 04] train_tile_acc=0.980 | lr=0.000316
# [circle ][Fold 19][Ep 05] train_tile_acc=0.986 | lr=0.000316
# [circle ][Fold 19] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 19] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 19][Ep 01] train_tile_acc=0.863 | lr=0.001000
# [meander][Fold 19][Ep 02] train_tile_acc=0.902 | lr=0.001000
# [meander][Fold 19][Ep 03] train_tile_acc=0.916 | lr=0.001000
# [meander][Fold 19][Ep 04] train_tile_acc=0.938 | lr=0.001000
# [meander][Fold 19][Ep 05] train_tile_acc=0.942 | lr=0.001000
# [meander][Fold 19][Ep 06] train_tile_acc=0.962 | lr=0.001000
# [meander][Fold 19][Ep 07] train_tile_acc=0.965 | lr=0.001000
# [meander][Fold 19][Ep 08] train_tile_acc=0.975 | lr=0.000100
# [meander][Fold 19][Ep 09] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 19][Ep 10] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 19] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 19] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 19][Ep 01] train_tile_acc=0.846 | lr=0.000316
# [spiral ][Fold 19][Ep 02] train_tile_acc=0.922 | lr=0.000316
# [spiral ][Fold 19][Ep 03] train_tile_acc=0.957 | lr=0.000316
# [spiral ][Fold 19][Ep 04] train_tile_acc=0.953 | lr=0.000316
# [spiral ][Fold 19][Ep 05] train_tile_acc=0.968 | lr=0.000316
# [spiral ][Fold 19] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 19] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H28 (Run 19) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H28 (Run 19) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H29 (RUN 20) ##############
# ################################################################################
#
# [circle ][Fold 20][Ep 01] train_tile_acc=0.830 | lr=0.000316
# [circle ][Fold 20][Ep 02] train_tile_acc=0.949 | lr=0.000316
# [circle ][Fold 20][Ep 03] train_tile_acc=0.969 | lr=0.000316
# [circle ][Fold 20][Ep 04] train_tile_acc=0.974 | lr=0.000316
# [circle ][Fold 20][Ep 05] train_tile_acc=0.983 | lr=0.000316
# [circle ][Fold 20] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 20] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 20][Ep 01] train_tile_acc=0.849 | lr=0.001000
# [meander][Fold 20][Ep 02] train_tile_acc=0.899 | lr=0.001000
# [meander][Fold 20][Ep 03] train_tile_acc=0.916 | lr=0.001000
# [meander][Fold 20][Ep 04] train_tile_acc=0.904 | lr=0.001000
# [meander][Fold 20][Ep 05] train_tile_acc=0.935 | lr=0.001000
# [meander][Fold 20][Ep 06] train_tile_acc=0.956 | lr=0.001000
# [meander][Fold 20][Ep 07] train_tile_acc=0.956 | lr=0.001000
# [meander][Fold 20][Ep 08] train_tile_acc=0.972 | lr=0.000100
# [meander][Fold 20][Ep 09] train_tile_acc=0.989 | lr=0.000100
# [meander][Fold 20][Ep 10] train_tile_acc=0.985 | lr=0.000100
# [meander][Fold 20] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 20] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 20][Ep 01] train_tile_acc=0.871 | lr=0.000316
# [spiral ][Fold 20][Ep 02] train_tile_acc=0.932 | lr=0.000316
# [spiral ][Fold 20][Ep 03] train_tile_acc=0.953 | lr=0.000316
# [spiral ][Fold 20][Ep 04] train_tile_acc=0.952 | lr=0.000316
# [spiral ][Fold 20][Ep 05] train_tile_acc=0.977 | lr=0.000316
# [spiral ][Fold 20] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 20] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H29 (Run 20) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H29 (Run 20) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H3 (RUN 21) ##############
# ################################################################################
#
# [circle ][Fold 21][Ep 01] train_tile_acc=0.832 | lr=0.000316
# [circle ][Fold 21][Ep 02] train_tile_acc=0.922 | lr=0.000316
# [circle ][Fold 21][Ep 03] train_tile_acc=0.949 | lr=0.000316
# [circle ][Fold 21][Ep 04] train_tile_acc=0.979 | lr=0.000316
# [circle ][Fold 21][Ep 05] train_tile_acc=0.982 | lr=0.000316
# [circle ][Fold 21] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 21] WINNER TEST (image): acc=0.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=1 tn=0 fn=0]
# [meander][Fold 21][Ep 01] train_tile_acc=0.870 | lr=0.001000
# [meander][Fold 21][Ep 02] train_tile_acc=0.925 | lr=0.001000
# [meander][Fold 21][Ep 03] train_tile_acc=0.946 | lr=0.001000
# [meander][Fold 21][Ep 04] train_tile_acc=0.955 | lr=0.001000
# [meander][Fold 21][Ep 05] train_tile_acc=0.960 | lr=0.001000
# [meander][Fold 21][Ep 06] train_tile_acc=0.969 | lr=0.001000
# [meander][Fold 21][Ep 07] train_tile_acc=0.971 | lr=0.001000
# [meander][Fold 21][Ep 08] train_tile_acc=0.991 | lr=0.000100
# [meander][Fold 21][Ep 09] train_tile_acc=0.996 | lr=0.000100
# [meander][Fold 21][Ep 10] train_tile_acc=0.999 | lr=0.000100
# [meander][Fold 21] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 21] WINNER TEST (image): acc=0.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=4 tn=0 fn=0]
# [spiral ][Fold 21][Ep 01] train_tile_acc=0.879 | lr=0.000316
# [spiral ][Fold 21][Ep 02] train_tile_acc=0.934 | lr=0.000316
# [spiral ][Fold 21][Ep 03] train_tile_acc=0.958 | lr=0.000316
# [spiral ][Fold 21][Ep 04] train_tile_acc=0.969 | lr=0.000316
# [spiral ][Fold 21][Ep 05] train_tile_acc=0.979 | lr=0.000316
# [spiral ][Fold 21] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 21] WINNER TEST (image): acc=0.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=4 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H3 (Run 21) ---
# pred=1 true=0 correct=0
#
# --- SUBJECT-LEVEL (Group) — H3 (Run 21) ---
# pred=1 true=0 correct=0
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H30 (RUN 22) ##############
# ################################################################################
#
# [circle ][Fold 22][Ep 01] train_tile_acc=0.813 | lr=0.000316
# [circle ][Fold 22][Ep 02] train_tile_acc=0.922 | lr=0.000316
# [circle ][Fold 22][Ep 03] train_tile_acc=0.955 | lr=0.000316
# [circle ][Fold 22][Ep 04] train_tile_acc=0.988 | lr=0.000316
# [circle ][Fold 22][Ep 05] train_tile_acc=0.985 | lr=0.000316
# [circle ][Fold 22] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 22] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 22][Ep 01] train_tile_acc=0.828 | lr=0.001000
# [meander][Fold 22][Ep 02] train_tile_acc=0.881 | lr=0.001000
# [meander][Fold 22][Ep 03] train_tile_acc=0.924 | lr=0.001000
# [meander][Fold 22][Ep 04] train_tile_acc=0.935 | lr=0.001000
# [meander][Fold 22][Ep 05] train_tile_acc=0.938 | lr=0.001000
# [meander][Fold 22][Ep 06] train_tile_acc=0.953 | lr=0.001000
# [meander][Fold 22][Ep 07] train_tile_acc=0.963 | lr=0.001000
# [meander][Fold 22][Ep 08] train_tile_acc=0.987 | lr=0.000100
# [meander][Fold 22][Ep 09] train_tile_acc=0.993 | lr=0.000100
# [meander][Fold 22][Ep 10] train_tile_acc=0.991 | lr=0.000100
# [meander][Fold 22] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 22] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
# [spiral ][Fold 22][Ep 01] train_tile_acc=0.858 | lr=0.000316
# [spiral ][Fold 22][Ep 02] train_tile_acc=0.921 | lr=0.000316
# [spiral ][Fold 22][Ep 03] train_tile_acc=0.956 | lr=0.000316
# [spiral ][Fold 22][Ep 04] train_tile_acc=0.966 | lr=0.000316
# [spiral ][Fold 22][Ep 05] train_tile_acc=0.972 | lr=0.000316
# [spiral ][Fold 22] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 22] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=4 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — H30 (Run 22) ---
# pred=0 true=0 correct=1
#
# --- SUBJECT-LEVEL (Group) — H30 (Run 22) ---
# pred=0 true=0 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST H31 (RUN 23) ##############
# ################################################################################
#
# [circle ][Fold 23][Ep 01] train_tile_acc=0.843 | lr=0.000316
# [circle ][Fold 23][Ep 02] train_tile_acc=0.937 | lr=0.000316
# [circle ][Fold 23][Ep 03] train_tile_acc=0.959 | lr=0.000316
# [circle ][Fold 23][Ep 04] train_tile_acc=0.981 | lr=0.000316
# [circle ][Fold 23][Ep 05] train_tile_acc=0.985 | lr=0.000316
# [circle ][Fold 23] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 23] WINNER TEST (image): acc=1.000  prec=0.000  recall=0.000  f1=0.000  [tp=0 fp=0 tn=1 fn=0]
# [meander][Fold 23][Ep 01] train_tile_acc=0.835 | lr=0.001000
# [meander][Fold 23][Ep 02] train_tile_acc=0.911 | lr=0.001000
# [meander][Fold 23][Ep 03] train_tile_acc=0.935 | lr=0.001000
# [meander][Fold 23][Ep 04] train_tile_acc=0.936 | lr=0.001000
# [meander][Fold 23][Ep 05] train_tile_acc=0.951 | lr=0.001000
# [meander][Fold 23][Ep 06] train_tile_acc=0.945 | lr=0.001000
# ...
# ############## SUBJECT-WISE LOSO — TEST P32 (RUN 60) ##############
# ################################################################################
#
# [circle ][Fold 60][Ep 01] train_tile_acc=0.830 | lr=0.000316
# [circle ][Fold 60][Ep 02] train_tile_acc=0.923 | lr=0.000316
# [circle ][Fold 60][Ep 03] train_tile_acc=0.965 | lr=0.000316
# [circle ][Fold 60][Ep 04] train_tile_acc=0.973 | lr=0.000316
# [circle ][Fold 60][Ep 05] train_tile_acc=0.983 | lr=0.000316
# [circle ][Fold 60] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 60] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=1 fp=0 tn=0 fn=0]
# [meander][Fold 60][Ep 01] train_tile_acc=0.850 | lr=0.001000
# [meander][Fold 60][Ep 02] train_tile_acc=0.907 | lr=0.001000
# [meander][Fold 60][Ep 03] train_tile_acc=0.936 | lr=0.001000
# [meander][Fold 60][Ep 04] train_tile_acc=0.946 | lr=0.001000
# [meander][Fold 60][Ep 05] train_tile_acc=0.955 | lr=0.001000
# [meander][Fold 60][Ep 06] train_tile_acc=0.965 | lr=0.001000
# [meander][Fold 60][Ep 07] train_tile_acc=0.953 | lr=0.001000
# [meander][Fold 60][Ep 08] train_tile_acc=0.987 | lr=0.000100
# [meander][Fold 60][Ep 09] train_tile_acc=0.985 | lr=0.000100
# [meander][Fold 60][Ep 10] train_tile_acc=0.992 | lr=0.000100
# [meander][Fold 60] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 60] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
# [spiral ][Fold 60][Ep 01] train_tile_acc=0.866 | lr=0.000316
# [spiral ][Fold 60][Ep 02] train_tile_acc=0.935 | lr=0.000316
# [spiral ][Fold 60][Ep 03] train_tile_acc=0.965 | lr=0.000316
# [spiral ][Fold 60][Ep 04] train_tile_acc=0.958 | lr=0.000316
# [spiral ][Fold 60][Ep 05] train_tile_acc=0.979 | lr=0.000316
# [spiral ][Fold 60] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 60] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — P32 (Run 60) ---
# pred=1 true=1 correct=1
#
# --- SUBJECT-LEVEL (Group) — P32 (Run 60) ---
# pred=1 true=1 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST P4 (RUN 61) ##############
# ################################################################################
#
# [circle ][Fold 61][Ep 01] train_tile_acc=0.835 | lr=0.000316
# [circle ][Fold 61][Ep 02] train_tile_acc=0.938 | lr=0.000316
# [circle ][Fold 61][Ep 03] train_tile_acc=0.971 | lr=0.000316
# [circle ][Fold 61][Ep 04] train_tile_acc=0.990 | lr=0.000316
# [circle ][Fold 61][Ep 05] train_tile_acc=0.981 | lr=0.000316
# [circle ][Fold 61] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 61] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=1 fp=0 tn=0 fn=0]
# [meander][Fold 61][Ep 01] train_tile_acc=0.853 | lr=0.001000
# [meander][Fold 61][Ep 02] train_tile_acc=0.900 | lr=0.001000
# [meander][Fold 61][Ep 03] train_tile_acc=0.931 | lr=0.001000
# [meander][Fold 61][Ep 04] train_tile_acc=0.942 | lr=0.001000
# [meander][Fold 61][Ep 05] train_tile_acc=0.954 | lr=0.001000
# [meander][Fold 61][Ep 06] train_tile_acc=0.963 | lr=0.001000
# [meander][Fold 61][Ep 07] train_tile_acc=0.972 | lr=0.001000
# [meander][Fold 61][Ep 08] train_tile_acc=0.983 | lr=0.000100
# [meander][Fold 61][Ep 09] train_tile_acc=0.995 | lr=0.000100
# [meander][Fold 61][Ep 10] train_tile_acc=0.993 | lr=0.000100
# [meander][Fold 61] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 61] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
# [spiral ][Fold 61][Ep 01] train_tile_acc=0.843 | lr=0.000316
# [spiral ][Fold 61][Ep 02] train_tile_acc=0.924 | lr=0.000316
# [spiral ][Fold 61][Ep 03] train_tile_acc=0.955 | lr=0.000316
# [spiral ][Fold 61][Ep 04] train_tile_acc=0.978 | lr=0.000316
# [spiral ][Fold 61][Ep 05] train_tile_acc=0.972 | lr=0.000316
# [spiral ][Fold 61] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 61] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — P4 (Run 61) ---
# pred=1 true=1 correct=1
#
# --- SUBJECT-LEVEL (Group) — P4 (Run 61) ---
# pred=1 true=1 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST P5 (RUN 62) ##############
# ################################################################################
#
# [circle ][Fold 62][Ep 01] train_tile_acc=0.838 | lr=0.000316
# [circle ][Fold 62][Ep 02] train_tile_acc=0.940 | lr=0.000316
# [circle ][Fold 62][Ep 03] train_tile_acc=0.975 | lr=0.000316
# [circle ][Fold 62][Ep 04] train_tile_acc=0.970 | lr=0.000316
# [circle ][Fold 62][Ep 05] train_tile_acc=0.993 | lr=0.000316
# [circle ][Fold 62] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 62] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=1 fp=0 tn=0 fn=0]
# [meander][Fold 62][Ep 01] train_tile_acc=0.853 | lr=0.001000
# [meander][Fold 62][Ep 02] train_tile_acc=0.911 | lr=0.001000
# [meander][Fold 62][Ep 03] train_tile_acc=0.932 | lr=0.001000
# [meander][Fold 62][Ep 04] train_tile_acc=0.945 | lr=0.001000
# [meander][Fold 62][Ep 05] train_tile_acc=0.940 | lr=0.001000
# [meander][Fold 62][Ep 06] train_tile_acc=0.965 | lr=0.001000
# [meander][Fold 62][Ep 07] train_tile_acc=0.967 | lr=0.001000
# [meander][Fold 62][Ep 08] train_tile_acc=0.987 | lr=0.000100
# [meander][Fold 62][Ep 09] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 62][Ep 10] train_tile_acc=0.997 | lr=0.000100
# [meander][Fold 62] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 62] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
# [spiral ][Fold 62][Ep 01] train_tile_acc=0.870 | lr=0.000316
# [spiral ][Fold 62][Ep 02] train_tile_acc=0.918 | lr=0.000316
# [spiral ][Fold 62][Ep 03] train_tile_acc=0.948 | lr=0.000316
# [spiral ][Fold 62][Ep 04] train_tile_acc=0.965 | lr=0.000316
# [spiral ][Fold 62][Ep 05] train_tile_acc=0.976 | lr=0.000316
# [spiral ][Fold 62] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 62] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — P5 (Run 62) ---
# pred=1 true=1 correct=1
#
# --- SUBJECT-LEVEL (Group) — P5 (Run 62) ---
# pred=1 true=1 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST P6 (RUN 63) ##############
# ################################################################################
#
# [circle ][Fold 63][Ep 01] train_tile_acc=0.838 | lr=0.000316
# [circle ][Fold 63][Ep 02] train_tile_acc=0.935 | lr=0.000316
# [circle ][Fold 63][Ep 03] train_tile_acc=0.966 | lr=0.000316
# [circle ][Fold 63][Ep 04] train_tile_acc=0.986 | lr=0.000316
# [circle ][Fold 63][Ep 05] train_tile_acc=0.983 | lr=0.000316
# [circle ][Fold 63] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 63] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=1 fp=0 tn=0 fn=0]
# [meander][Fold 63][Ep 01] train_tile_acc=0.866 | lr=0.001000
# [meander][Fold 63][Ep 02] train_tile_acc=0.901 | lr=0.001000
# [meander][Fold 63][Ep 03] train_tile_acc=0.919 | lr=0.001000
# [meander][Fold 63][Ep 04] train_tile_acc=0.929 | lr=0.001000
# [meander][Fold 63][Ep 05] train_tile_acc=0.946 | lr=0.001000
# [meander][Fold 63][Ep 06] train_tile_acc=0.969 | lr=0.001000
# [meander][Fold 63][Ep 07] train_tile_acc=0.965 | lr=0.001000
# [meander][Fold 63][Ep 08] train_tile_acc=0.981 | lr=0.000100
# [meander][Fold 63][Ep 09] train_tile_acc=0.994 | lr=0.000100
# [meander][Fold 63][Ep 10] train_tile_acc=0.999 | lr=0.000100
# [meander][Fold 63] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 63] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
# [spiral ][Fold 63][Ep 01] train_tile_acc=0.877 | lr=0.000316
# [spiral ][Fold 63][Ep 02] train_tile_acc=0.924 | lr=0.000316
# [spiral ][Fold 63][Ep 03] train_tile_acc=0.954 | lr=0.000316
# [spiral ][Fold 63][Ep 04] train_tile_acc=0.963 | lr=0.000316
# [spiral ][Fold 63][Ep 05] train_tile_acc=0.985 | lr=0.000316
# [spiral ][Fold 63] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 63] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — P6 (Run 63) ---
# pred=1 true=1 correct=1
#
# --- SUBJECT-LEVEL (Group) — P6 (Run 63) ---
# pred=1 true=1 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST P7 (RUN 64) ##############
# ################################################################################
#
# [circle ][Fold 64][Ep 01] train_tile_acc=0.828 | lr=0.000316
# [circle ][Fold 64][Ep 02] train_tile_acc=0.915 | lr=0.000316
# [circle ][Fold 64][Ep 03] train_tile_acc=0.968 | lr=0.000316
# [circle ][Fold 64][Ep 04] train_tile_acc=0.983 | lr=0.000316
# [circle ][Fold 64][Ep 05] train_tile_acc=0.987 | lr=0.000316
# [circle ][Fold 64] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 64] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=1 fp=0 tn=0 fn=0]
# [meander][Fold 64][Ep 01] train_tile_acc=0.854 | lr=0.001000
# [meander][Fold 64][Ep 02] train_tile_acc=0.915 | lr=0.001000
# [meander][Fold 64][Ep 03] train_tile_acc=0.920 | lr=0.001000
# [meander][Fold 64][Ep 04] train_tile_acc=0.933 | lr=0.001000
# [meander][Fold 64][Ep 05] train_tile_acc=0.948 | lr=0.001000
# [meander][Fold 64][Ep 06] train_tile_acc=0.953 | lr=0.001000
# [meander][Fold 64][Ep 07] train_tile_acc=0.967 | lr=0.001000
# [meander][Fold 64][Ep 08] train_tile_acc=0.989 | lr=0.000100
# [meander][Fold 64][Ep 09] train_tile_acc=0.990 | lr=0.000100
# [meander][Fold 64][Ep 10] train_tile_acc=0.998 | lr=0.000100
# [meander][Fold 64] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 64] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
# [spiral ][Fold 64][Ep 01] train_tile_acc=0.856 | lr=0.000316
# [spiral ][Fold 64][Ep 02] train_tile_acc=0.922 | lr=0.000316
# [spiral ][Fold 64][Ep 03] train_tile_acc=0.950 | lr=0.000316
# [spiral ][Fold 64][Ep 04] train_tile_acc=0.968 | lr=0.000316
# [spiral ][Fold 64][Ep 05] train_tile_acc=0.969 | lr=0.000316
# [spiral ][Fold 64] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 64] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — P7 (Run 64) ---
# pred=1 true=1 correct=1
#
# --- SUBJECT-LEVEL (Group) — P7 (Run 64) ---
# pred=1 true=1 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST P8 (RUN 65) ##############
# ################################################################################
#
# [circle ][Fold 65][Ep 01] train_tile_acc=0.838 | lr=0.000316
# [circle ][Fold 65][Ep 02] train_tile_acc=0.924 | lr=0.000316
# [circle ][Fold 65][Ep 03] train_tile_acc=0.966 | lr=0.000316
# [circle ][Fold 65][Ep 04] train_tile_acc=0.988 | lr=0.000316
# [circle ][Fold 65][Ep 05] train_tile_acc=0.991 | lr=0.000316
# [circle ][Fold 65] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 65] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=1 fp=0 tn=0 fn=0]
# [meander][Fold 65][Ep 01] train_tile_acc=0.847 | lr=0.001000
# [meander][Fold 65][Ep 02] train_tile_acc=0.922 | lr=0.001000
# [meander][Fold 65][Ep 03] train_tile_acc=0.933 | lr=0.001000
# [meander][Fold 65][Ep 04] train_tile_acc=0.938 | lr=0.001000
# [meander][Fold 65][Ep 05] train_tile_acc=0.946 | lr=0.001000
# [meander][Fold 65][Ep 06] train_tile_acc=0.965 | lr=0.001000
# [meander][Fold 65][Ep 07] train_tile_acc=0.974 | lr=0.001000
# [meander][Fold 65][Ep 08] train_tile_acc=0.984 | lr=0.000100
# [meander][Fold 65][Ep 09] train_tile_acc=0.990 | lr=0.000100
# [meander][Fold 65][Ep 10] train_tile_acc=0.999 | lr=0.000100
# [meander][Fold 65] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 65] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
# [spiral ][Fold 65][Ep 01] train_tile_acc=0.881 | lr=0.000316
# [spiral ][Fold 65][Ep 02] train_tile_acc=0.942 | lr=0.000316
# [spiral ][Fold 65][Ep 03] train_tile_acc=0.965 | lr=0.000316
# [spiral ][Fold 65][Ep 04] train_tile_acc=0.973 | lr=0.000316
# [spiral ][Fold 65][Ep 05] train_tile_acc=0.975 | lr=0.000316
# [spiral ][Fold 65] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 65] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — P8 (Run 65) ---
# pred=1 true=1 correct=1
#
# --- SUBJECT-LEVEL (Group) — P8 (Run 65) ---
# pred=1 true=1 correct=1
#
# ################################################################################
# ############## SUBJECT-WISE LOSO — TEST P9 (RUN 66) ##############
# ################################################################################
#
# [circle ][Fold 66][Ep 01] train_tile_acc=0.832 | lr=0.000316
# [circle ][Fold 66][Ep 02] train_tile_acc=0.935 | lr=0.000316
# [circle ][Fold 66][Ep 03] train_tile_acc=0.951 | lr=0.000316
# [circle ][Fold 66][Ep 04] train_tile_acc=0.974 | lr=0.000316
# [circle ][Fold 66][Ep 05] train_tile_acc=0.992 | lr=0.000316
# [circle ][Fold 66] Feature dim: 512  (Xtr=(65, 512), Xte=(1, 512))
# [circle ][Fold 66] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=1 fp=0 tn=0 fn=0]
# [meander][Fold 66][Ep 01] train_tile_acc=0.851 | lr=0.001000
# [meander][Fold 66][Ep 02] train_tile_acc=0.916 | lr=0.001000
# [meander][Fold 66][Ep 03] train_tile_acc=0.921 | lr=0.001000
# [meander][Fold 66][Ep 04] train_tile_acc=0.949 | lr=0.001000
# [meander][Fold 66][Ep 05] train_tile_acc=0.961 | lr=0.001000
# [meander][Fold 66][Ep 06] train_tile_acc=0.950 | lr=0.001000
# [meander][Fold 66][Ep 07] train_tile_acc=0.959 | lr=0.001000
# [meander][Fold 66][Ep 08] train_tile_acc=0.988 | lr=0.000100
# [meander][Fold 66][Ep 09] train_tile_acc=0.991 | lr=0.000100
# [meander][Fold 66][Ep 10] train_tile_acc=0.995 | lr=0.000100
# [meander][Fold 66] Feature dim: 512  (Xtr=(260, 512), Xte=(4, 512))
# [meander][Fold 66] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
# [spiral ][Fold 66][Ep 01] train_tile_acc=0.860 | lr=0.000316
# [spiral ][Fold 66][Ep 02] train_tile_acc=0.920 | lr=0.000316
# [spiral ][Fold 66][Ep 03] train_tile_acc=0.948 | lr=0.000316
# [spiral ][Fold 66][Ep 04] train_tile_acc=0.975 | lr=0.000316
# [spiral ][Fold 66][Ep 05] train_tile_acc=0.985 | lr=0.000316
# [spiral ][Fold 66] Feature dim: 1024  (Xtr=(260, 1024), Xte=(4, 1024))
# [spiral ][Fold 66] WINNER TEST (image): acc=1.000  prec=1.000  recall=1.000  f1=1.000  [tp=4 fp=0 tn=0 fn=0]
#
# --- SUBJECT-LEVEL (Flat) — P9 (Run 66) ---
# pred=1 true=1 correct=1
#
# --- SUBJECT-LEVEL (Group) — P9 (Run 66) ---
# pred=1 true=1 correct=1
#
# === PER-DRAW IMAGE ACCURACIES — WINNERS (MACRO over LOSO runs) ===
# circle  : macro_img_acc=0.8636  (from 66 runs)
# meander : macro_img_acc=0.9394  (from 66 runs)
# spiral  : macro_img_acc=0.9318  (from 66 runs)
#
# === PER-DRAW IMAGE ACCURACIES — WINNERS (MICRO pooled) ===
# circle  : micro_img_acc=0.8636  [57/66]
# meander : micro_img_acc=0.9394  [248/264]
# spiral  : micro_img_acc=0.9318  [246/264]
#
# === PER-DRAW IMAGE PRF — WINNERS (MICRO pooled) ===
# circle  : acc=0.864  prec=0.848  recall=0.875  f1=0.862  [tp=28 fp=5 tn=29 fn=4]
# meander : acc=0.939  prec=0.952  recall=0.922  f1=0.937  [tp=118 fp=6 tn=130 fn=10]
# spiral  : acc=0.932  prec=0.930  recall=0.930  f1=0.930  [tp=119 fp=9 tn=127 fn=9]
#
# === SUBJECT-LEVEL ACCURACIES — WINNERS (MACRO over LOSO runs) ===
# Flat-majority (macro):   0.9394
# Group-majority (macro):  0.9394
#
# === SUBJECT-LEVEL ACCURACIES — WINNERS (MICRO pooled) ===
# Flat-majority (micro):   0.9394  [62/66]
# Group-majority (micro):  0.9394  [62/66]
#
# === SUBJECT-LEVEL PRF — WINNERS (MICRO pooled) ===
# Flat-majority:  acc=0.939  prec=0.938  recall=0.938  f1=0.938  [tp=30 fp=2 tn=32 fn=2]
# Group-majority: acc=0.939  prec=0.938  recall=0.938  f1=0.938  [tp=30 fp=2 tn=32 fn=2]
